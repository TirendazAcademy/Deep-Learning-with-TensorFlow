# %% [markdown]
# <a href="https://colab.research.google.com/github/TirendazAcademy/Deep-Learning-with-TensorFlow/blob/main/Pratical-Keras-Tutorials/Model_Subclassing_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading

# %%
from sklearn.datasets import  fetch_california_housing
housing = fetch_california_housing()

# %%
for i in housing:
  print(i)
# Out:
# data
# target
# frame
# target_names
# feature_names
# DESCR

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.model_selection import train_test_split

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
from tensorflow import keras

# %%
class WideAndDeepModel(tf.keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)  # needed to support naming the model
        self.norm_layer_wide = tf.keras.layers.Normalization()
        self.norm_layer_deep = tf.keras.layers.Normalization()
        self.hidden1 = tf.keras.layers.Dense(units, activation=activation)
        self.hidden2 = tf.keras.layers.Dense(units, activation=activation)
        self.main_output = tf.keras.layers.Dense(1)
    def call(self, inputs):
        input_wide, input_deep = inputs
        norm_wide = self.norm_layer_wide(input_wide)
        norm_deep = self.norm_layer_deep(input_deep)
        hidden1 = self.hidden1(norm_deep)
        hidden2 = self.hidden2(hidden1)
        concat = tf.keras.layers.concatenate([norm_wide, hidden2])
        output = self.main_output(concat)
        return output

# %%
tf.random.set_seed(42)
model = WideAndDeepModel(30, activation="relu", name="my_model")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer,
              metrics=["RootMeanSquaredError"])

# %%
X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]

# %% [markdown]
# # Model Training

# %%
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)

history = model.fit((X_train_wide, X_train_deep),
                    y_train,
                    validation_data=((X_valid_wide, X_valid_deep), y_valid),
                    epochs=10)
# Out:
# Epoch 1/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 1.5266 - loss: 2.4547 - val_RootMeanSquaredError: 0.7770 - val_loss: 0.6037
# Epoch 2/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.7218 - loss: 0.5220 - val_RootMeanSquaredError: 0.6502 - val_loss: 0.4227
# Epoch 3/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6655 - loss: 0.4432 - val_RootMeanSquaredError: 0.6231 - val_loss: 0.3882
# Epoch 4/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6449 - loss: 0.4161 - val_RootMeanSquaredError: 0.6357 - val_loss: 0.4041
# Epoch 5/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6337 - loss: 0.4018 - val_RootMeanSquaredError: 0.6525 - val_loss: 0.4258
# Epoch 6/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6253 - loss: 0.3912 - val_RootMeanSquaredError: 0.7578 - val_loss: 0.5743
# Epoch 7/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.6183 - loss: 0.3824 - val_RootMeanSquaredError: 0.8285 - val_loss: 0.6865
# Epoch 8/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - RootMeanSquaredError: 0.6122 - loss: 0.3749 - val_RootMeanSquaredError: 1.4409 - val_loss: 2.0763
# Epoch 9/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6077 - loss: 0.3694 - val_RootMeanSquaredError: 2.1452 - val_loss: 4.6019
# Epoch 10/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6133 - loss: 0.3763 - val_RootMeanSquaredError: 2.3351 - val_loss: 5.4529

# %% [markdown]
# # Model Evaluation

# %%
eval_results = model.evaluate((X_test_wide, X_test_deep), y_test)
eval_results
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6169 - loss: 0.3808
# [0.37370389699935913, 0.6113132834434509]

# %% [markdown]
# # Prediction

# %%
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]

# %%
y_pred= model.predict((X_new_wide, X_new_deep))
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# array([[0.4202266],
#        [1.5949552],
#        [3.4973302]], dtype=float32)

# %%
y_test[:3]
# Out:
# array([0.477  , 0.458  , 5.00001])

# %% [markdown]
# Let's connect [YouTube](http://youtube.com/tirendazacademy) | [Medium](http://tirendazacademy.medium.com) | [Twitter](http://twitter.com/tirendazacademy) | [Instagram](https://www.instagram.com/tirendazacademy) | [GitHub](http://github.com/tirendazacademy) | [Linkedin](https://www.linkedin.com/in/tirendaz-academy) | [Kaggle](https://www.kaggle.com/tirendazacademy) 😎
