# %% [markdown]
# <a href="https://colab.research.google.com/github/TirendazAcademy/Deep-Learning-with-TensorFlow/blob/main/Computer-Vision-with-TensorFlow/Introduction-to-CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction-to-CNN

# %%
from sklearn.datasets import load_sample_images
import tensorflow as tf

# %% [markdown]
# # Loading images

# %%
images = load_sample_images()["images"]

# %%
images[0].shape
# Out:
# (427, 640, 3)

# %% [markdown]
# # Data Preprocessing

# %%
images = tf.keras.layers.CenterCrop(height=80, width=120)(images)
images = tf.keras.layers.Rescaling(scale=1/255)(images)

# %%
images.shape
# Out:
# TensorShape([2, 80, 120, 3])

# %% [markdown]
# # Applying filters

# %%
conv_layer = tf.keras.layers.Conv2D(filters=32, kernel_size=7)

# %%
fmaps = conv_layer(images)

# %%
fmaps.shape
# Out:
# TensorShape([2, 74, 114, 32])

# %% [markdown]
# # Adding the padding

# %%
conv_layer = tf.keras.layers.Conv2D(filters=32, kernel_size=7, padding = "same")

# %%
fmaps = conv_layer(images)

# %%
fmaps.shape
# Out:
# TensorShape([2, 80, 120, 32])

# %% [markdown]
# # Exporing kernels and biases

# %%
kernels, biases = conv_layer.get_weights()

# %%
kernels.shape
# Out:
# (7, 7, 3, 32)

# %%
biases.shape
# Out:
# (32,)

# %% [markdown]
# # Applying the Pooling

# %%
max_pool = tf.keras.layers.MaxPool2D(pool_size=2)

# %%
output = max_pool(images)

# %%
output.shape
# Out:
# TensorShape([2, 40, 60, 3])

# %% [markdown]
# # Global Average Pooling

# %%
global_avg_pool = tf.keras.layers.GlobalAvgPool2D()

# %%
global_avg_pool(images)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0.6368122 , 0.595365  , 0.5791015 ],
#        [0.76797295, 0.26939029, 0.11366344]], dtype=float32)>

# %% [markdown]
# Let's connect 🔗 [YouTube](https://www.youtube.com/c/TirendazAcademy) | [Medium](https://tirendazacademy.medium.com) | [Twitter](https://twitter.com/EvrenOzkip) | [Instagram](https://www.instagram.com/tirendazacademy) | [GitHub](https://github.com/TirendazAcademy) | [LinkedIn](https://www.linkedin.com/in/tirendaz-academy)
